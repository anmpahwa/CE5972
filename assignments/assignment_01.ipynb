# %% [markdown]
# # Assignment 1
#
# ---
#
# 1. **Road Maintenance Problem**
#
#     The Chennai Unified Metropolitan Transport Authority (CUMTA) is planning to allocate ₹5,00,000 to maintain two major arterial routes, R1 and R2. R1 has a maintenance cost of ₹50,000 per kilometer, while R2 amounts for ₹30,000 per kilometer for road maintenance. To ensure a minimal level of service on both arterial routes, CUMTA must finance upkeep of at least 5 kilometers on both routes.
#
#     - Formulate an optimisation problem to optimise the total length of roads maintained. (3)
#
#     - Clearly explain the objective function, decision variables, as well as technical and domain constraints. (1)
#
#     - State the necessary assumptions. (2)
#
#     - Appropiately categorise the optimisation problem. (1)
#
# 2. **Delhi-Chennai High-Speed Rail Problem**
#
#     The National High Speed Rail Coroporation (NHRC) plans to operate two types of high-speed bullet trains, T1 and T2, between Delhi and Chennai, cutting down travel time between two cities from 32 hours to less than 12 hours. T1 is an express service stopping at Vijaywada, Nagpur, Bhopal, and Agra on its way from Chennai to Delhi. On the other hand, T2 is an economy service with additional stops at Gudur, Balharshah, and Jhansi. Note, T1 has a capacity of 800 and runs at an operational cost of ₹250 per km, while T2 can serve 1200 passengers with an operational cost of ₹200 per km. Further, the daily passenger demand on the route is uncertain and follows a normal distribution with a mean of 5000 passengers and a standard deviation of 500.
#
#     - Formulate an optimisation problem to optimise the running costs of the high-speed trains between Delhi and Chennai ensuring 95% service level. (3)
#
#     - Clearly indicate the objective function, decision variables, as well as technical and domain constraints. (1)
#
#     - State the necessary assumptions. (2)
#
#     - Appropiately categorise the optimisation problem. (1)
#
# 3. **Holiday-Special Train Scheduling Problem**
#
#     The Indian Railways needs to schedule holiday-special trains between Chennai and Hyderabad to cater to the increased demand during the Pongal festival. Specifically, the surge in passenger demand for the three days prior to the festival is 10k, 15k, and 12k passengers, respectively. If the holiday-special trains can serve upto 1500 passengers at an operating cost of ₹150 per km, then,
#
#     - Formulate an optimization problem to optimise railway operations. (3)
#
#     - Clearly indicate the objective function, decision variables, as well as technical and domain constraints. (1)
#
#     - State the necessary assumptions. (2)
#
#     - Appropiately categorise the optimisation problem. (1)
#
# 4. **Amazon Last-Mile Delivery Problem**
#
#     Amazon plans to operate three types of delivery fleets T1 (diesel van), T2 (electric van), and T3 (motorised two-wheeler) in Chennai. The table below presents key characteristics of these three delivery vehicles - purchase cost, operatonal cost (fuel cost + maintenance cost + driver wage), and capacity.
#
#       | Vehicle Type          | Purchase Cost (₹)        | Operational cost (₹ per km) | Capacity (number of customers) |
#       |-----------------------|--------------------------|-----------------------------|--------------------------------|
#       | Diesel Van            | 6,00,000                 | ₹7 + ₹3 + ₹25 = ₹35         | 200                            |
#       | Electric Van          | 9,00,000                 | ₹2 + ₹1 + ₹25 = ₹28         | 150                            |
#       | Motorised two-wheeler | 1,50,000                 | ₹3 + ₹1 + ₹25 = ₹29         | 20                             |
#
#     Use the following notations.
#
#     - number of delivery vehicles purchased:  $f_i \ \forall \in [1,3]$
#
#     - number of delivery tours per vehicle: $m_i \ \forall \in [1,3]$
#
#     - number of customer per delivery tour: $c_i \ \forall \in [1,3]$
#
#     Answer the following questions
#
#     - Formulate the daily amoritsed fixed cost assuming a planning horizon of 7 years with 330 working days, and a discount rate of 3%. (3)
#
#     - Formulate the operational cost if the length of one delivery tour is given by $l_i = 2 \rho + k c_i / \sqrt \delta$, where $\rho = 25$ is the long-haul distance, $k = 0.57$ is last-mile constant, and $\delta = 25$ is customer density. (3)
#
#     - Formulate the constraints if a total of 5000 customers need to be served with at least 5 diesel and 10 electric vans. (3)
